# %% [markdown]
# # Recurrent Neural Networks
# So far, the neural network architectures we have been using have been simple in the sense that they take in a single fixed size input and give a single fixed size output. What if we wanted to model something like language where we want to feed in different length words? Another issue is that each output is only dependent on the current input. It has no 'memory' of previous inputs. Recurrent neural networks address both these issues.
#
# They do this by having an internal hidden state which can be thought of as a form of memory. At each time step, the new hidden state is calculated as a function of the previous hidden state and the current input. This hidden state can then be used to represent your output or can be put through another function to compute the outputs. When we say function we are referring to the same one used in standard neural network: linear combination followed by an activation function.
#
# ### $h_t = f(x_t, h_{t-1})$
#
# As shown in the diagram below, which uses a further function to compute the output $o$ from the hidden state $s$, there are three matrices of parameters which we are trying to optimize: U, V and W. The diagram also demonstrates how these networks can be unfolded to show the variables at various time steps.
#
# ![](rnn.jpg)
#
# Standard neural networks can only model one to one relationships while RNNs are extremely flexible in terms of input-output structures which is one of the reasons they are so powerful. You can imagine something like one to many being used to feed in a single image from which a caption is sequentially produced or a many to one being used to feed in a sentence sequentially and give a single output describing the sentiment of the sentence.
#
# ![](rnnlayouts.jpeg)
#
# ### Optimization
# Surprisingly, with this increased complexity in structure, the optimization method does not become any more difficult. Despite having a different name, back-propagation through time, it is essentially the same thing. All you do is feed in your sequence sequentially to get the output, as usual. You then just calculate your error at each timestep and sum it as opposed to calculating the error at a single timestep like standard neural networks. Then you can use gradient descent to update your weights iteratively until you are satisfied with your network's performance.
#
# RNNS are generally slower to optimize than standard neural networks as the output at each time step is dependent on the previous output so the operations cannot be parallelized.
#
# For a long time it was considered difficult to train RNNs due to two problems called vanishing and exploding gradients. These problems also exist in standard neural network but are greatly emphasized in RNNs. However, modern techniques such as LSTM cells have greatly reduced this difficulty.

# %% [markdown]
# ## Implementation
# We are going to be implementing a one-to-one character level text prediction model. We will be sequentially feeding in a single character and asking our network to predict the next character based on the 'memory' stored in the hidden units of all the previous characters.
#
# As always, we begin by importing the required libraries.

# %%
# %matplotlib notebook
import torch
import numpy as np
from torch.autograd import Variable
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %% [markdown]
# For this particular task, we will need to do quite a bit of pre-processing. We need to find the number of unique characters in our training text and give each one a unique number so we can one-hot encode them.<br>
# We start by reading the file, converting all letters to lowercase to reduce the number of characters we need to model, then defining a function which takes in the text and gives up back a dictionary mapping each letter to a unique number.

# %%
#open our text file and read all the data into the rawtxt variable
with open('lyrics.txt', 'r',encoding="utf-8") as file: #encoding="latin1"
    #for t in file: 
     #   print(t)
      #  break
    rawtxt = file.read()
    print(file.readline())

#turn all of the text into lowercase as it will reduce the number of characters that our algorithm needs to learn
rawtxt = rawtxt.lower()#.split()
#print(rawtxt)
#returns a dictionary that allows us to map from a unique number to a unique character in our text
def create_map(rawtxt):
    #print(rawtxt)
    #palab=[]
    #for word in rawtxt:
        #print(word)
       # if word not in palab:
            #print(word)
        #    palab.append(word)
    #print(palab)        
        
    letters = list(set(rawtxt)) #returns the list of unique characters in our raw text
    #print(letters)
    lettermap = dict(enumerate(letters)) #created the dictionary mapping
    print(lettermap)

    return lettermap

num_to_let = create_map(rawtxt) #store the dictionary mapping from numbers to characters in a variable
let_to_num = dict(zip(num_to_let.values(), num_to_let.keys())) #create the reverse mapping so we can map from a character to a unique number

nchars = len(num_to_let) #number of unique characters in our text file
print("num_to_let: ", num_to_let)
for x in num_to_let:
    print(type(x), type(num_to_let[x]))
    break
# Out:
# {0: ']', 1: 'f', 2: 's', 3: 'p', 4: 'd', 5: 'k', 6: '”', 7: '4', 8: 'y', 9: '-', 10: '2', 11: '5', 12: '‘', 13: '6', 14: 'q', 15: 'u', 16: '[', 17: ':', 18: 'm', 19: 't', 20: 'x', 21: 'v', 22: ' ', 23: 'h', 24: '!', 25: '\n', 26: '/', 27: ')', 28: "'", 29: 'z', 30: '3', 31: ',', 32: 'c', 33: 'a', 34: 'i', 35: 'n', 36: '1', 37: '0', 38: '"', 39: ';', 40: 'e', 41: '?', 42: 'l', 43: 'b', 44: '(', 45: '.', 46: 'g', 47: '7', 48: 'w', 49: 'j', 50: 'ś', 51: '9', 52: 'o', 53: '“', 54: 'r', 55: '’'}
# num_to_let:  {0: ']', 1: 'f', 2: 's', 3: 'p', 4: 'd', 5: 'k', 6: '”', 7: '4', 8: 'y', 9: '-', 10: '2', 11: '5', 12: '‘', 13: '6', 14: 'q', 15: 'u', 16: '[', 17: ':', 18: 'm', 19: 't', 20: 'x', 21: 'v', 22: ' ', 23: 'h', 24: '!', 25: '\n', 26: '/', 27: ')', 28: "'", 29: 'z', 30: '3', 31: ',', 32: 'c', 33: 'a', 34: 'i', 35: 'n', 36: '1', 37: '0', 38: '"', 39: ';', 40: 'e', 41: '?', 42: 'l', 43: 'b', 44: '(', 45: '.', 46: 'g', 47: '7', 48: 'w', 49: 'j', 50: 'ś', 51: '9', 52: 'o', 53: '“', 54: 'r', 55: '’'}
# <class 'int'> <class 'str'>

# %% [raw]
# We now define a function which takes in text and a dictionary and maps each character in the text to the value specified for it in the dictionary. We then use this to map all of our text into the unique numbers for each character so it can be used with our RNN model. The labels are specified as the input but shifted by one time step as the label for each input is the character which comes after it.

# %%
def maparray(txt, mapdict):
    
    txt = list(txt)

    #iterate through our text and change the value for each character to its mapped value
    for k, letter in enumerate(txt):
        txt[k] = mapdict[letter]

    txt = np.array(txt)
    return txt

#map our raw text into our input variables using the function defined earlier and passing in the mapping from letters to numbers
X = maparray(rawtxt, let_to_num)
Y = np.roll(X, -1, axis=0) #our label is the next character so roll shifts our array by one timestep
print(X)
print(Y)
print(np.shape(X))
#conver to torch tensors so we can use them in our torch model
X = torch.LongTensor(X)
Y = torch.LongTensor(Y)

#Example Aiz
q=np.array([1,2,3,4])
qq=np.roll(q,-1, axis=0)
print(q)
print(qq)
# Out:
# [33  8 40 ... 35 46 25]
# [ 8 40 31 ... 46 25 33]
# (24442,)
# [1 2 3 4]
# [2 3 4 1]

# %% [markdown]
# Define our model which takes in variables defining its structure as parameters. The encoder converts each unique number into an embedding which is fed into the rnn model. The RNN calculates the hidden state which is converted into an output through a fully connected layer called the decoder.<br>
# We also define the init_hidden function which outputs us a tensor of zeros of the required size for the hidden state.

# %%
class RNN(torch.nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super().__init__()
        #store input parameters in the object so we can use them later on
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers

        #required functions for model
        self.encoder = torch.nn.Embedding(input_size, input_size)
        self.rnn = torch.nn.GRU(input_size, hidden_size, n_layers, batch_first=True)
        self.decoder = torch.nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        x = self.encoder(x.view(1, -1)) #encode our input into a vector embedding
        output, hidden = self.rnn(x.view(1, 1, -1), hidden) #calculate the output from our rnn based on our input and previous hidden state
        output = self.decoder(output.view(1, -1)) #calculate our output based on output of rnn

        return output, hidden

    def init_hidden(self):
        return Variable(torch.zeros(self.n_layers, 1, self.hidden_size)) #initialize our hidden state to a matrix of 0s

# %% [markdown]
# Instantiate our model, define the appropriate hyper-parameters, cost function and optimizer. We will be training on ranom samples from the text of length chunk_size so it is what batch size is to normal neural networks.<br>
# We also define the function which return a random chunk from the text which we can use to train out model.

# %%
#hyper-params
lr = 0.001
no_epochs = 20
chunk_size = 100 #the length of the sequences which we will optimize over

myrnn = RNN(nchars, 512, nchars, 1) #instantiate our model from the class defined earlier
criterion = torch.nn.CrossEntropyLoss() #define our cost function
optimizer = torch.optim.Adam(myrnn.parameters(), lr=lr) #choose optimizer
input = torch.randn(1, 5, requires_grad=True)
target = torch.empty(1, dtype=torch.long).random_(5)
p=0
p=+1
print(p)
print(input, input.size())
print(target,target.size())
print(criterion(input,target))
#return a random batch for training
def random_chunk(chunk_size):
    k = np.random.randint(0, len(X)-chunk_size)
    return X[k:k+chunk_size], Y[k:k+chunk_size]
# Out:
# 1
# tensor([[-0.8464, -0.1850, -1.2477, -1.0628, -0.7114]], requires_grad=True) torch.Size([1, 5])
# tensor([1]) torch.Size([1])
# tensor(1.0536, grad_fn=<NllLossBackward>)

# %% [markdown]
# Define the axes for plotting our cost per epoch. Define the training loop, sequentially feeding in a random chunk of text, summing the cost for each character in the sequence (backpropagation through time) and calculating the gradients to update our weights.

# %%
#for plotting costs
costs = []
plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('Epoch')
ax.set_ylabel('Cost')
ax.set_xlim(0, no_epochs-1)
plt.show()


#training loop
def train(no_epochs):
    for epoch in range(no_epochs):
        totcost = 0 #stores the cost per epoch
        generated = '' #stores the text generated by our model each epoch
        #given our chunk size, how many chunks do we need to optimize over to have gone thorough our whole dataset
        for _ in range(len(X)//chunk_size):
            h = myrnn.init_hidden() #initialize our hidden state to 0s
            cost = 0 #cost for this chunk
            x, y = random_chunk(chunk_size) #get a random sequence chunk to train
            x, y = Variable(x), Variable(y) #turn into variables to be used with our model
            #sequentially input each character in our sequence and calculate loss
            for i in range(chunk_size):
                out, h = myrnn.forward(x[i], h) #calculate outputs based on input and previous hidden state

                #based on our output, what character does our network predict is next?
                _, outl = out.data.max(1) 
                
                #print(torch.LongTensor(outl[0].item()))
                #print("outl", outl)
                #print(type(outl[0]))
                #print("num_to_let: ", num_to_let[int(outl[0].item())])
                letter = num_to_let[int(outl[0].item())]
                generated+=letter #add the predicted letter to our generated sequence
                #print("out:",out,"shape", out.size())
                #print("y[i]: ",torch.LongTensor([y[i].item()]), "shape", torch.LongTensor([y[i].item()]).size())
                #print("criterion: ", criterion(out, torch.LongTensor([y[i].item()])))
                cost += criterion(out, torch.LongTensor([y[i].item()])) #add the cost for this input to the cost for this current chunk
                #print("cost: ", cost)
                                     
            #based on the sum of the cost for this sequence (backpropagation through time) calculate the gradients and update our weights
            optimizer.zero_grad() 
            cost.backward()
            optimizer.step()
            #print("cost ",cost.data)
            totcost += cost.data #add the cost of this sequence to the cost of this epoch
        totcost /= len(X)//chunk_size #divide by the number of chunks per epoch to get average cost per epoch

        #append the cost to the array and plot
        costs.append(totcost)
        ax.plot(costs, 'b')
        fig.canvas.draw()

        print('Epoch ', epoch+1, ' Avg cost/chunk: ', totcost)
        print('Generated text: ', generated[0:750], '\n')
        
train(no_epochs)
# Out:
# <img src="data:image/png;base64,..." width="640">
# cost  tensor(278.4790)
# cost  tensor(264.9105)
# cost  tensor(259.7962)
# cost  tensor(290.7884)
# cost  tensor(261.1816)
# cost  tensor(251.8695)
# cost  tensor(271.6242)
# cost  tensor(297.5654)
# cost  tensor(291.3660)
# cost  tensor(265.1991)
# cost  tensor(281.2394)
# cost  tensor(294.1218)
# cost  tensor(256.3619)
# cost  tensor(252.4153)
# cost  tensor(258.8741)
# cost  tensor(228.1505)
# cost  tensor(272.4464)
# cost  tensor(257.1411)
# cost  tensor(271.6133)
# cost  tensor(251.4492)
# cost  tensor(239.6781)
# cost  tensor(224.4899)
# cost  tensor(259.0881)
# cost  tensor(219.0646)
# cost  tensor(268.2200)
# cost  tensor(279.4806)
# cost  tensor(240.2311)
# cost  tensor(239.4693)
# cost  tensor(225.7301)
# cost  tensor(322.4894)
# cost  tensor(228.1427)
# cost  tensor(262.3134)
# cost  tensor(233.1695)
# cost  tensor(230.8745)
# cost  tensor(236.0390)
# cost  tensor(222.6591)
# cost  tensor(248.0511)
# cost  tensor(253.4679)
# cost  tensor(225.8673)
# cost  tensor(268.1706)
# cost  tensor(228.5884)
# cost  tensor(182.3685)
# cost  tensor(220.0784)
# cost  tensor(207.9992)
# cost  tensor(192.3782)
# cost  tensor(244.0428)
# cost  tensor(262.3708)
# cost  tensor(235.1517)
# cost  tensor(160.2952)
# cost  tensor(248.7722)
# cost  tensor(251.9546)
# cost  tensor(241.3189)
# cost  tensor(213.6088)
# cost  tensor(250.7670)
# cost  tensor(264.1339)
# cost  tensor(269.4468)
# cost  tensor(209.9964)
# cost  tensor(230.7497)
# cost  tensor(220.2268)
# cost  tensor(206.4001)
# cost  tensor(223.3143)
# cost  tensor(190.3052)
# cost  tensor(244.6709)
# cost  tensor(221.9668)
# cost  tensor(268.5201)
# cost  tensor(173.8264)
# cost  tensor(218.5163)
# cost  tensor(191.8627)
# cost  tensor(179.8631)
# cost  tensor(168.7286)
# cost  tensor(129.4594)
# cost  tensor(202.6454)
# cost  tensor(150.6109)
# cost  tensor(141.5712)
# cost  tensor(150.7406)
# cost  tensor(158.8555)
# cost  tensor(156.4315)
# cost  tensor(51.1473)
# cost  tensor(177.4807)
# cost  tensor(202.3906)
# cost  tensor(202.2103)
# cost  tensor(63.4451)
# cost  tensor(193.0684)
# cost  tensor(192.1519)
# cost  tensor(205.7149)
# cost  tensor(108.1150)
# cost  tensor(166.3297)
# cost  tensor(201.1184)
# cost  tensor(208.5284)
# cost  tensor(187.5607)
# cost  tensor(218.2144)
# cost  tensor(103.2131)
# cost  tensor(203.5251)
# cost  tensor(200.7961)
# cost  tensor(193.8258)
# cost  tensor(227.0158)
# cost  tensor(88.6969)
# cost  tensor(204.0704)
# cost  tensor(133.8800)
# cost  tensor(177.1757)
# cost  tensor(72.1204)
# cost  tensor(175.3936)
# cost  tensor(307.9101)
# cost  tensor(166.7465)
# cost  tensor(141.1461)
# cost  tensor(64.1785)
# cost  tensor(200.9385)
# cost  tensor(168.5976)
# cost  tensor(213.1939)
# cost  tensor(181.9889)
# cost  tensor(233.8520)
# cost  tensor(186.8389)
# cost  tensor(163.5767)
# cost  tensor(234.1713)
# cost  tensor(143.2531)
# cost  tensor(150.5251)
# cost  tensor(206.8189)
# cost  tensor(209.5919)
# cost  tensor(214.0699)
# cost  tensor(158.1199)
# cost  tensor(129.3912)
# cost  tensor(142.8676)
# cost  tensor(225.6309)
# cost  tensor(193.1778)
# cost  tensor(186.3628)
# cost  tensor(180.7710)
# cost  tensor(146.6702)
# cost  tensor(177.9403)
# cost  tensor(109.6461)
# cost  tensor(118.7455)
# cost  tensor(166.4995)
# cost  tensor(196.4015)
# cost  tensor(158.6741)
# cost  tensor(115.8590)
# cost  tensor(57.3396)
# cost  tensor(64.8837)
# Epoch  1  Avg cost/chunk:  tensor(204.3583)
# Generated text:  aeaau  yt   wi e e whuwt  p urwt  wtti  a pll heaarwereee iikeue ttppal he
# wet woua  (heue ttppil'pae
# t t to o iheu' ttlpil'iol he
# ta te eee iheu' ttlpal he
# t t to h theue ttlp t to o tit'iol he
# ihht h tt the    tt 'itto  it  'lhe  ptt      phe  t     the tii    tt te  to  iih' iio    th wh  th    tun  th te th te t  hi    th   li th   ti  t   tt t    th     t   l     t t    h  t  h  tt  t  t   bo thneeu tt  tiin th tite thneeu tt titn htti n tou t    thtti n thit  tile tt tot tit  ttte  lih  tteu    (th  ton tttiinh (hit tonn    ttotonte tntonn  tn toinebn  tin  (ou too   ton  ta   thntinn tn u tn      (t    ottone tene (il ioen ton    to   iot enen  tatn  (onn  tanhnmn  ion   ih  t  tontonn-  aon  ton aa an aoe tann (n  aon  n  asaun ton
#
# cost  tensor(113.5020)
# cost  tensor(230.1811)
# cost  tensor(150.1375)
# cost  tensor(159.7026)
# cost  tensor(187.8492)
# cost  tensor(108.6044)
# cost  tensor(83.6253)
# cost  tensor(145.8815)
# cost  tensor(187.8742)
# cost  tensor(158.7455)
# cost  tensor(189.2772)
# cost  tensor(159.0386)
# cost  tensor(183.9530)
# cost  tensor(23.5101)
# cost  tensor(109.4466)
# cost  tensor(141.1552)
# cost  tensor(223.8265)
# cost  tensor(145.3880)
# cost  tensor(182.8122)
# cost  tensor(46.3668)
# cost  tensor(148.4704)
# cost  tensor(117.4211)
# cost  tensor(201.7779)
# cost  tensor(45.3172)
# cost  tensor(174.2516)
# cost  tensor(126.4491)
# cost  tensor(194.8066)
# Epoch  2  Avg cost/chunk:  tensor(150.6811)
# Generated text:  erwuooe  fn ais aam
# aalkiay enf to the fomt  toke  "bitch  i did thet "
# [-rok r i[uhnyy dan't tanna er  wno ioe fhme   iover totel  tuailk at,tt tha fui  w0aw  wn yhe fhn aoatirte tf yhe fan  iinl n'  rk,an the femnaght toot bf yaoght an the femeang nant(ave y sunk wnout tou  faneloxttn
#  y gnow jhete tiou  fom cenliomn and sou  fomf coingand you  fothan  tn ahat yondains, inn totd tot  yhet you too ody wann th thkkiinout thenehes wnd yhewehet yaewwhe woall   ond yhereelk  ihewthet  yn yaenteeyk wp,litch) bit down
# (hol' up,lhl down (il bitch) bhit down (ol bitch) bi humble
# (hol' up, hol' up, hoe  toue totet  tur tom  tves iiv ioe fhtl n aoodaiwhe r  woaer   tnsetlinn,ahle  thth
# ..([hook:
#
# bond the wunk,(nowkou whnt
# the wunk,
#
# (a want the wu
#
# cost  tensor(145.9443)
# cost  tensor(121.1193)
# cost  tensor(164.0716)
# cost  tensor(107.9223)
# cost  tensor(121.5097)
# cost  tensor(106.9434)
# cost  tensor(172.3075)
# cost  tensor(151.1099)
# cost  tensor(96.5230)
# cost  tensor(95.3777)
# cost  tensor(148.2635)
# cost  tensor(135.0303)
# cost  tensor(47.7504)
# cost  tensor(24.4834)
# cost  tensor(20.7095)
# cost  tensor(200.6558)
# cost  tensor(148.8685)
# cost  tensor(115.5417)
# cost  tensor(146.2058)
# cost  tensor(101.2428)
# cost  tensor(155.7686)
# cost  tensor(180.0990)
# cost  tensor(102.8804)
# cost  tensor(141.6622)
# cost  tensor(184.8650)
# cost  tensor(155.1969)
# cost  tensor(183.4524)
# cost  tensor(20.9647)
# cost  tensor(175.4005)
# cost  tensor(156.0023)
# cost  tensor(50.4260)
# cost  tensor(164.8539)
# cost  tensor(162.1150)
# cost  tensor(54.5424)
# cost  tensor(149.8612)
# cost  tensor(115.1811)
# cost  tensor(153.3253)
# cost  tensor(94.0917)
# cost  tensor(26.6067)
# cost  tensor(170.5479)
# cost  tensor(118.2978)
# cost  tensor(110.5608)
# cost  tensor(149.4292)
# cost  tensor(86.9105)
# cost  tensor(93.7391)
# cost  tensor(131.9485)
# cost  tensor(175.3085)
# cost  tensor(65.5111)
# cost  tensor(112.9813)
# cost  tensor(134.9964)
# cost  tensor(126.9181)
# cost  tensor(104.0297)
# cost  tensor(172.4511)
# cost  tensor(159.4774)
# cost  tensor(100.8124)
# cost  tensor(90.5405)
# cost  tensor(29.6898)
# cost  tensor(64.7849)
# cost  tensor(27.1674)
# cost  tensor(200.7391)
# cost  tensor(95.4698)
# cost  tensor(137.9601)
# cost  tensor(32.4304)
# cost  tensor(113.6387)
# cost  tensor(51.9920)
# cost  tensor(84.5520)
# cost  tensor(97.0102)
# cost  tensor(30.7413)
# cost  tensor(80.6460)
# cost  tensor(113.2128)
# cost  tensor(168.2026)
# cost  tensor(143.4970)
# cost  tensor(123.0288)
# cost  tensor(23.8090)
# cost  tensor(33.5845)
# cost  tensor(123.3327)
# cost  tensor(139.8748)
# cost  tensor(38.5452)
# cost  tensor(108.7372)
# cost  tensor(169.9946)
# cost  tensor(64.6499)
# cost  tensor(92.9344)
# cost  tensor(176.3501)
# cost  tensor(175.0925)
# cost  tensor(67.7010)
# cost  tensor(21.8731)
# cost  tensor(120.4168)
# cost  tensor(77.6417)
# cost  tensor(108.2000)
# cost  tensor(67.5175)
# cost  tensor(139.5800)
# cost  tensor(23.4691)
# cost  tensor(108.0659)
# cost  tensor(104.2942)
# cost  tensor(162.8503)
# cost  tensor(109.0579)
# cost  tensor(26.3671)
# cost  tensor(151.9410)
# cost  tensor(180.4858)
# cost  tensor(28.0196)
# cost  tensor(57.1263)
# cost  tensor(146.1459)
# cost  tensor(202.0124)
# cost  tensor(135.8687)
# cost  tensor(17.2030)
# cost  tensor(21.2249)
# cost  tensor(165.9957)
# cost  tensor(46.3207)
# cost  tensor(33.3913)
# cost  tensor(108.2245)
# cost  tensor(63.9945)
# cost  tensor(96.6755)
# cost  tensor(94.2758)
# cost  tensor(121.4133)
# cost  tensor(95.3755)
# cost  tensor(78.6856)
# cost  tensor(89.7519)
# cost  tensor(196.5415)
# cost  tensor(99.7314)
# cost  tensor(156.1817)
# cost  tensor(63.2996)
# cost  tensor(14.8087)
# cost  tensor(19.3410)
# cost  tensor(93.0141)
# cost  tensor(148.2466)
# cost  tensor(157.0524)
# cost  tensor(129.4867)
# cost  tensor(121.6331)
# cost  tensor(113.1381)
# cost  tensor(22.2407)
# cost  tensor(54.5541)
# cost  tensor(69.5281)
# cost  tensor(82.5088)
# cost  tensor(138.0295)
# cost  tensor(181.6435)
# cost  tensor(165.6071)
# Epoch  3  Avg cost/chunk:  tensor(110.1967)
# Generated text:  n ancone tomda iealltigga nn ty dna
# i n’t te loll  ide my dna
# iaaglin’ sa l mn ide my dna
# iroer iiiutol  ind wou san't wen aiom iaene ya wammtooom ihet suund mike moutic justice, puutic justice,pou dathy thme hin' ihet s aecc
# etid taipacelllor mhreeve
#
#
# n yynein’  i  ie mi n'  tollr mhiuld mever fiv ifety ity  iyhet y  aow
#
#
# [hook]
#
# yvery ody wannato thlkiabout the thes wnd who what who the wealestht dt an wy dalte beowdi
# i got tay to  botty on e you lot tyttonfhe wxtret
# porl tp tn your hlooke iigg saldelk
# pouanan a soneay  foretchin’ sh aovva
# cost  tensor(64.4014)
# cost  tensor(26.5577)
# cost  tensor(51.8084)
# cost  tensor(95.2577)
# cost  tensor(120.5225)
# cost  tensor(140.6248)
# cost  tensor(89.1438)
# cost  tensor(86.3622)
# cost  tensor(27.1796)
# cost  tensor(111.4970)
# cost  tensor(166.4426)
# cost  tensor(77.4668)
# cost  tensor(28.3354)
# cost  tensor(58.7913)
# cost  tensor(76.4229)
# cost  tensor(58.9456)
# cost  tensor(93.3505)
# cost  tensor(209.6048)
# cost  tensor(87.4665)
# cost  tensor(54.3540)
# cost  tensor(84.8960)
# cost  tensor(72.0174)
# cost  tensor(33.8778)
# cost  tensor(56.9416)
# cost  tensor(178.0576)
# cost  tensor(69.9339)
# cost  tensor(16.7079)
# cost  tensor(17.0180)
# cost  tensor(28.8263)
# cost  tensor(125.9214)
# cost  tensor(78.8371)
# cost  tensor(13.1362)
# cost  tensor(30.2891)
# cost  tensor(54.7428)
# cost  tensor(38.4787)
# cost  tensor(51.4089)
# cost  tensor(15.1954)
# Epoch  4  Avg cost/chunk:  tensor(87.3366)
# Generated text:  s the sore
# t don't aee compeon  t ste tome hing narh whrl
# the samd of the samdsenes, the sell that’teoe, puutic justice,you we e fontew to thes aafe iit ion  nai iou son r  rst r itlaan t waite loess t d phet iy hreor nhs aoopd i'l calk n’ koetic justice, puetic justice,y  i sald mou lhit i mlow r i)
# we want the funk?(nowyou want the funk?)
# we want the funk
# (now if i give you the funk, you gon' t  ttt e ess  iou   ahanl ond peght seeure you wovbloee, i.s
#
# [hook - kendrick lamar:]
# you can get itt ething narh whrl
# the land of the lamdmines, the lell that’s an earth s
# i got l bloe to aick
# i donhe bamdeettwkttd itt
# wet the wunk wff yy dnck  that d n’t noght a made t play fockeng kp tour hhele hcn
# ibitch where you when i was walkin'?
# now i run
#
# cost  tensor(83.0375)
# cost  tensor(71.3235)
# cost  tensor(58.8667)
# cost  tensor(197.6596)
# cost  tensor(79.3899)
# cost  tensor(56.2327)
# cost  tensor(147.4969)
# cost  tensor(36.5985)
# cost  tensor(94.9940)
# cost  tensor(35.8125)
# cost  tensor(69.3281)
# cost  tensor(35.3094)
# cost  tensor(91.4667)
# cost  tensor(107.4383)
# cost  tensor(104.4281)
# cost  tensor(15.2131)
# cost  tensor(73.5994)
# cost  tensor(75.3005)
# cost  tensor(26.9044)
# cost  tensor(124.3558)
# cost  tensor(37.3378)
# cost  tensor(24.5591)
# cost  tensor(24.7660)
# cost  tensor(75.3274)
# cost  tensor(174.0988)
# cost  tensor(100.5608)
# cost  tensor(146.4747)
# cost  tensor(80.7950)
# cost  tensor(111.4486)
# cost  tensor(102.8056)
# cost  tensor(21.9355)
# cost  tensor(55.3079)
# cost  tensor(16.3502)
# cost  tensor(47.6709)
# cost  tensor(145.6543)
# cost  tensor(15.9399)
# cost  tensor(91.7640)
# cost  tensor(54.1154)
# cost  tensor(60.3464)
# cost  tensor(99.8766)
# cost  tensor(45.6356)
# cost  tensor(55.6506)
# ihnk yhrett  momvetyte tn  ce, tetdi, ixelettss  tld yrot r bethenksate tonveption
# i rransform like this, serform like this,ias yoahep's new wo rhr
# b ron't somvepplrtng my power focl of resent
# ent
# resentment that shrned on a s deep dopression
# bound my elf shreamin
# w[hoodat sigga ihassing mhat ai wrowt ng of yyy aykeaiyndtyki
# yet ihe wunk wff yy ftukes mtm roe pteo g shit
# hennessy and crown vic, my memory been g
#
# cost  tensor(65.8083)
# cost  tensor(22.1722)
# cost  tensor(84.8856)
# cost  tensor(68.9799)
# cost  tensor(133.3091)
# cost  tensor(94.6643)
# cost  tensor(38.3999)
# cost  tensor(62.2753)
# cost  tensor(36.5467)
# cost  tensor(19.2082)
# cost  tensor(75.4587)
# cost  tensor(34.8431)
# cost  tensor(83.1869)
# cost  tensor(40.7183)
# cost  tensor(64.0936)
# cost  tensor(92.3804)
# cost  tensor(55.2089)
# cost  tensor(13.5096)
# cost  tensor(11.6169)
# cost  tensor(78.6529)
# cost  tensor(51.4704)
# cost  tensor(105.0804)
# cost  tensor(23.9932)
# cost  tensor(147.7735)
# cost  tensor(77.3763)
# cost  tensor(81.3089)
# cost  tensor(38.1792)
# cost  tensor(46.7904)
# cost  tensor(78.5143)
# cost  tensor(32.9453)
# cost  tensor(98.3691)
# cost  tensor(19.5530)
# cost  tensor(18.6837)
# cost  tensor(93.1479)
# cost  tensor(43.8424)
# cost  tensor(63.3357)
# cost  tensor(70.0753)
# cost  tensor(35.2806)
# cost  tensor(54.4039)
# cost  tensor(109.6053)
# cost  tensor(86.4996)
# cost  tensor(43.9069)
# cost  tensor(42.4044)
# cost  tensor(45.7516)
# cost  tensor(84.2657)
# cost  tensor(31.2560)
# cost  tensor(68.4348)
# cost  tensor(55.9061)
# cost  tensor(52.6181)
# cost  tensor(58.0228)
# cost  tensor(36.3879)
# cost  tensor(68.8238)
# cost  tensor(124.7074)
# cost  tensor(64.9911)
# cost  tensor(62.3756)
# cost  tensor(63.2244)
# cost  tensor(78.3379)
# cost  tensor(59.5704)
# cost  tensor(89.3361)
# cost  tensor(64.3114)
# cost  tensor(50.8818)
# cost  tensor(12.6031)
# cost  tensor(28.4544)
# cost  tensor(17.3583)
# cost  tensor(18.5766)
# cost  tensor(52.6607)
# cost  tensor(39.7308)
# cost  tensor(47.5449)
# cost  tensor(97.5532)
# cost  tensor(42.8377)
# cost  tensor(30.2495)
# cost  tensor(25.5801)
# cost  tensor(54.7411)
# cost  tensor(57.2548)
# cost  tensor(46.6519)
# cost  tensor(62.8476)
# cost  tensor(65.1528)
# cost  tensor(28.0386)
# cost  tensor(57.3711)
# cost  tensor(143.1504)
# cost  tensor(59.3176)
# cost  tensor(94.2069)
# cost  tensor(23.3491)
# cost  tensor(86.4580)
# cost  tensor(33.6294)
# cost  tensor(30.8587)
# cost  tensor(131.5249)
# cost  tensor(30.9293)
# cost  tensor(35.0157)
# cost  tensor(59.5211)
# cost  tensor(18.5531)
# cost  tensor(16.2785)
# cost  tensor(78.1050)
# cost  tensor(111.8226)
# cost  tensor(70.2123)
# cost  tensor(30.7822)
# cost  tensor(107.7419)
# cost  tensor(40.1356)
# cost  tensor(74.9453)
# cost  tensor(83.9255)
# cost  tensor(62.1732)
# cost  tensor(44.3762)
# cost  tensor(59.8778)
# cost  tensor(17.6686)
# cost  tensor(68.9479)
# cost  tensor(49.3259)
# cost  tensor(41.5870)
# cost  tensor(40.5293)
# cost  tensor(33.8984)
# cost  tensor(118.5422)
# cost  tensor(24.6818)
# cost  tensor(31.1089)
# cost  tensor(14.5082)
# cost  tensor(55.8224)
# cost  tensor(62.8370)
# cost  tensor(33.8421)
# cost  tensor(67.7655)
# cost  tensor(88.2462)
# cost  tensor(44.6268)
# cost  tensor(31.5578)
# cost  tensor(15.4793)
# cost  tensor(143.3378)
# cost  tensor(24.7124)
# cost  tensor(34.7186)
# cost  tensor(31.7577)
# cost  tensor(40.6935)
# cost  tensor(29.3619)
# cost  tensor(18.1630)
# cost  tensor(36.1377)
# cost  tensor(44.6844)
# cost  tensor(14.1825)
# cost  tensor(33.0574)
# cost  tensor(64.7801)
# cost  tensor(64.1196)
# cost  tensor(42.9214)
# cost  tensor(64.6246)
# Epoch  6  Avg cost/chunk:  tensor(54.2090)
# Generated text:  e ond prrdy, hhe wanna go and party
# nigga lon't ssrrobkh por tath thet a arin higga  that a n't rondethene wou when i was walkin'
#
# now i run the game  got the whole world talkin' (king kunta)
# everybodbhet anemy pama and ty baby iao boo thelty aanlion titkin' out the wamrt buildin' soolsoolal yeah,tulahe wrme
#
# i geaember 9ou was conflicted,mistsing your onsluence
# somethoes i wod tha wame
# abasing muknle yxtrome
# s
# snd ixcellemt te n the wxtrassarl
# and ssatntsens that the wunk wourleard and iaasitih ,
# boom aomplon to sonvsess, it’s shl theshsn' dnl tround
# nn't so hin' iew kut a flow af new democu anside ty dna
# i got hustle though, ambition, flow, inside my dna
# i gas bor  like this, since one lbxrth bh es been suessed
# iin't so coress, jigha so
#
# cost  tensor(25.5837)
# cost  tensor(42.9353)
# cost  tensor(47.2125)
# cost  tensor(34.7496)
# cost  tensor(34.9921)
# cost  tensor(46.3269)
# cost  tensor(43.9277)
# cost  tensor(43.8610)
# cost  tensor(21.1339)
# cost  tensor(6.5991)
# cost  tensor(23.3401)
# cost  tensor(22.5517)
# cost  tensor(23.9834)
# cost  tensor(16.0377)
# cost  tensor(101.1793)
# cost  tensor(80.5370)
# cost  tensor(11.9310)
# cost  tensor(57.7745)
# cost  tensor(50.1033)
# cost  tensor(27.3573)
# cost  tensor(42.4951)
# cost  tensor(44.0705)
# cost  tensor(57.1715)
# cost  tensor(25.0461)
# cost  tensor(43.1341)
# cost  tensor(17.6628)
# cost  tensor(29.6793)
# cost  tensor(47.9610)
# cost  tensor(81.8299)
# cost  tensor(44.6100)
# cost  tensor(69.8166)
# cost  tensor(39.2223)
# cost  tensor(32.1356)
# cost  tensor(45.6359)
# cost  tensor(23.1683)
# cost  tensor(21.2560)
# even if master listenin', iover youreng  und dauas
# rs
# rip ridaz, p-funkers, mexicans, they fuck with you,asians, they fuck with you, oob ke  iitin' on the wo
# and seeesin' in a villa
# sippin' from a grammy and walkin' in the huildin'
# diame   tannificent
#  call all the sasters queens
# we all on the same taam, blues and parus, no colors ainn tf my sana and yy doby boo boo
# thenty mell on walkin' out the court luildin'
# wou woo
# wh yeah fuck u
#
# [verybody wann to talk about who thas and who that
# who tha wealest and who wack, who white or w womplloive disord rs son ,dnd daughters
# barricade
#
# cost  tensor(68.1900)
# cost  tensor(54.8347)
# cost  tensor(34.2087)
# cost  tensor(43.8368)
# cost  tensor(17.8296)
# cost  tensor(40.2772)
# cost  tensor(19.4090)
# cost  tensor(17.2216)
# cost  tensor(16.7752)
# cost  tensor(34.3725)
# cost  tensor(20.8865)
# cost  tensor(49.7933)
# cost  tensor(11.8752)
# cost  tensor(103.3749)
# cost  tensor(27.6289)
# cost  tensor(54.4000)
# cost  tensor(22.5420)
# cost  tensor(67.2335)
# cost  tensor(10.3846)
# cost  tensor(21.1223)
# cost  tensor(47.8660)
# cost  tensor(33.5344)
# cost  tensor(31.6546)
# cost  tensor(32.1416)
# cost  tensor(55.0455)
# cost  tensor(28.3920)
# cost  tensor(82.8651)
# cost  tensor(100.3003)
# cost  tensor(25.6373)
# cost  tensor(40.9125)
# cost  tensor(57.8907)
# cost  tensor(13.7118)
# cost  tensor(60.9038)
# cost  tensor(43.7342)
# cost  tensor(18.8599)
# cost  tensor(41.8907)
# cost  tensor(32.4624)
# cost  tensor(42.6293)
# cost  tensor(55.3847)
# cost  tensor(13.4159)
# cost  tensor(17.2886)
# cost  tensor(44.9305)
# cost  tensor(29.2567)
# cost  tensor(40.5495)
# cost  tensor(57.9423)
# cost  tensor(40.8383)
# cost  tensor(169.8988)
# cost  tensor(39.9722)
# cost  tensor(17.3437)
# cost  tensor(20.4327)
# cost  tensor(20.6828)
# cost  tensor(31.9598)
# cost  tensor(43.2900)
# cost  tensor(32.1303)
# cost  tensor(27.8875)
# cost  tensor(43.5043)
# cost  tensor(17.3462)
# cost  tensor(145.7183)
# cost  tensor(30.1605)
# cost  tensor(56.4561)
# cost  tensor(78.1268)
# cost  tensor(13.4340)
# cost  tensor(24.9104)
# cost  tensor(24.5927)
# cost  tensor(50.0354)
# cost  tensor(31.2802)
# cost  tensor(38.5280)
# cost  tensor(20.8834)
# cost  tensor(38.4544)
# cost  tensor(30.9561)
# cost  tensor(124.5651)
# cost  tensor(34.9377)
# cost  tensor(39.3329)
# cost  tensor(14.4244)
# cost  tensor(34.2714)
# cost  tensor(28.9714)
# cost  tensor(29.2397)
# cost  tensor(61.2062)
# cost  tensor(50.1462)
# cost  tensor(34.1811)
# cost  tensor(45.6604)
# cost  tensor(179.2259)
# cost  tensor(27.2073)
# cost  tensor(59.6538)
# cost  tensor(55.0083)
# cost  tensor(11.1452)
# cost  tensor(55.0736)
# cost  tensor(28.9900)
# cost  tensor(52.8891)
# cost  tensor(47.0433)
# cost  tensor(18.7969)
# cost  tensor(18.2612)
# cost  tensor(31.5856)
# cost  tensor(24.2817)
# Epoch  18  Avg cost/chunk:  tensor(18.6797)
# Generated text:  ta ssssale motel, we didn't have noweere to stay
# at 29, i've done so well, hit cartwheel in my pxtath sanl ae on shaniqua's phone
#
# [hook]]
# i been a-1 since day one, you niggas boo boo
# your home boy, ytteuat on surve, every letter here's true
# living my life in the margin and that metaphor was proof
# iann poetic justice, put it in a song
# y[verse 2 - kendrick lamar:]
# ivery sime i write these words, thnbecs thstes like kool aid for the analysts
# girl, i can buy your ass the world with my paystub
# ooh t e cairitual, my spirit do no better, but i told him
# "i can't sugarcoat the answer for you, this is txtlrs
# se coecked out in second grade
# when i was 9, on-sale motel, we didn't have nowhere to stay
# attot tt, you can get it
# aou can get it, you can get
#
# cost  tensor(10.2511)
# cost  tensor(26.6378)
# cost  tensor(27.2249)
# cost  tensor(21.8122)
# cost  tensor(7.8090)
# cost  tensor(13.9153)
# cost  tensor(17.7914)
# cost  tensor(20.2894)
# cost  tensor(23.0838)
# cost  tensor(14.1355)
# cost  tensor(13.2292)
# cost  tensor(17.3825)
# cost  tensor(23.2848)
# cost  tensor(13.3570)
# cost  tensor(16.4274)
# cost  tensor(17.2106)
# cost  tensor(21.1016)
# cost  tensor(22.5842)
# cost  tensor(17.6691)
# cost  tensor(31.9888)
# cost  tensor(17.7239)
# cost  tensor(38.7862)
# cost  tensor(22.5516)
# cost  tensor(6.8043)
# cost  tensor(8.7661)
# cost  tensor(19.5833)
# cost  tensor(4.9360)
# cost  tensor(19.1643)
# cost  tensor(15.1403)
# cost  tensor(26.8943)
# cost  tensor(12.9826)
# cost  tensor(25.7441)
# cost  tensor(13.9053)
# cost  tensor(20.9373)
# cost  tensor(15.9693)
# cost  tensor(20.2520)
# cost  tensor(15.8734)
# cost  tensor(16.0442)
# cost  tensor(14.4484)
# cost  tensor(17.7047)
# cost  tensor(41.1789)
# cost  tensor(13.5906)
# cost  tensor(12.8174)
# cost  tensor(11.3446)
# cost  tensor(14.2520)
# cost  tensor(11.6380)
# cost  tensor(33.5606)
# cost  tensor(24.4016)
# cost  tensor(10.8069)
# cost  tensor(26.3048)
# cost  tensor(23.4983)
# cost  tensor(11.9844)
# cost  tensor(17.3092)
# cost  tensor(20.8689)
# cost  tensor(12.0688)
# cost  tensor(28.7373)
# cost  tensor(23.8304)
# cost  tensor(8.8652)
# cost  tensor(20.3032)
# cost  tensor(22.8360)
# cost  tensor(37.6639)
# cost  tensor(16.4414)
# cost  tensor(18.5519)
# cost  tensor(17.0916)
# cost  tensor(18.2484)
# cost  tensor(24.6741)
# cost  tensor(26.7886)
# cost  tensor(16.2878)
# cost  tensor(23.0614)
# cost  tensor(13.2979)
# cost  tensor(16.4881)
# cost  tensor(40.7481)
# cost  tensor(26.8225)
# cost  tensor(6.4593)
# cost  tensor(30.6252)
# cost  tensor(26.4433)
# cost  tensor(27.9098)
# cost  tensor(19.1845)
# cost  tensor(6.9347)
# cost  tensor(8.4441)
# cost  tensor(9.9299)
# cost  tensor(13.4745)
# cost  tensor(21.0696)
# cost  tensor(23.4398)
# cost  tensor(20.8654)
# cost  tensor(9.7574)
# cost  tensor(15.4356)
# cost  tensor(13.0511)
# cost  tensor(16.7735)
# cost  tensor(32.7440)
# cost  tensor(31.3983)
# cost  tensor(25.2185)
# cost  tensor(12.9721)
# cost  tensor(11.0574)
# cost  tensor(28.1963)
# cost  tensor(30.4263)
# cost  tensor(19.5094)
# cost  tensor(6.3272)
# cost  tensor(11.7571)
# cost  tensor(15.0950)
# cost  tensor(13.0570)
# cost  tensor(16.2710)
# cost  tensor(22.7009)
# cost  tensor(28.6818)
# cost  tensor(12.1114)
# cost  tensor(18.2402)
# cost  tensor(25.7743)
# cost  tensor(11.0907)
# cost  tensor(18.3784)
# cost  tensor(14.0958)
# cost  tensor(22.0853)
# cost  tensor(18.3886)
# cost  tensor(24.3417)
# cost  tensor(13.9347)
# cost  tensor(27.5777)
# cost  tensor(21.8212)
# cost  tensor(15.0292)
# cost  tensor(23.2215)
# cost  tensor(20.5229)
# cost  tensor(31.3623)
# cost  tensor(10.9964)
# cost  tensor(11.8265)
# cost  tensor(15.1769)
# cost  tensor(25.3666)
# cost  tensor(16.8744)
# cost  tensor(35.6161)
# cost  tensor(17.3063)
# cost  tensor(19.5493)
# cost  tensor(19.7804)
# cost  tensor(9.6994)
# cost  tensor(29.7042)
# cost  tensor(26.4224)
# cost  tensor(24.3869)
# cost  tensor(17.6651)
# cost  tensor(20.2902)
# cost  tensor(22.9376)
# Epoch  19  Avg cost/chunk:  tensor(18.7102)
# Generated text:  te bumble
#
# hol' up bitch) sit down
# (hit down hol' up lil bitch)
# be humble (bitch)
# (hol' up, hol' up,doyrder tnsthe street, it be bodies in the hour
# ghetto bird be on the street, paramedics on the dialettrhored to
# antisocial, extrovert
# and excellent mean the extra work
# and absentness what the fuck honng kuar
# this that put-the-kids-to-bed
# this that i got, i got, i got, i got,realness, i just kill shnout no politics in rap, my nigga
# my lil homie stunna deuce ain't never comin' back, my nigga
# so youu gnow i'd ten toes down
# even if master listenin', cover your ears, he 'bout no sention
#
# [vook]
#
# darnao nil homie stunna deuce ain't never comin' back, my nigga
# so you better go hard every time you juthn mn on-sale motelf we didn't have nowhere to st
#
# cost  tensor(20.6474)
# cost  tensor(16.5426)
# cost  tensor(17.4747)
# cost  tensor(18.0013)
# cost  tensor(16.7386)
# cost  tensor(24.1076)
# cost  tensor(21.6975)
# cost  tensor(17.1935)
# cost  tensor(23.6519)
# cost  tensor(23.8540)
# cost  tensor(16.6791)
# cost  tensor(26.8198)
# cost  tensor(13.7990)
# cost  tensor(21.4833)
# cost  tensor(18.0665)
# cost  tensor(14.9393)
# cost  tensor(10.8286)
# cost  tensor(16.0297)
# cost  tensor(23.0249)
# cost  tensor(12.1705)
# cost  tensor(14.3010)
# cost  tensor(24.2948)
# cost  tensor(22.3690)
# cost  tensor(33.7661)
# cost  tensor(36.2194)
# cost  tensor(16.7463)
# cost  tensor(18.9206)
# cost  tensor(25.9506)
# Epoch  20  Avg cost/chunk:  tensor(19.1345)
# Generated text:    bigga
# with the world behind him
# "ife ain't shit but a fat vagina
# screamin' aannie are you ok? ann nlole with mi barrio?
# oh, yeah? tell 'em they can run it for the cardio
# oh, yeah? everythin' is ever d douve hhen you swerve
# i want that interference, it's coherent, i can hear it, uh-huh
# that's your chke iou down fight on your mamma's conch in polo socks, aye
# this shit way too crazy, aye
# you do not for iveness
# yeah, yeah, yeah, seah, soldier's dna
# born inside tha beast
# my expertise checked out in e cin
# sou ain't shit without a tody on your belt
# you ain't shit without a ticket on your plate
# you e dedigetter yet, where your friends and 'em? i really wanna cnow you all
# i really wanna show you ofud ween gone since
# don’t ask about no camera back

# %% [markdown]
# The generated text above picks the most probable next character each time. This is not the best way to do it as our model will be deterministic so it will produce the same text over and over again. To get it producing different text, we should instead sample from the probability distribution of possible next letters output by the network. That is what we will do with the next function.

# %%
def generate(prime_str='a', str_len=150, temperature=0.75):
    generated = prime_str
    
    #initialize hidden state
    h = myrnn.init_hidden()
    
    prime_str = maparray(prime_str, let_to_num)
    x = Variable(torch.LongTensor(prime_str))
    
    #primes our hidden state with the input string
    for i in range(len(x)):
        out, h = myrnn.forward(x[i], h)
    
    x = x[-1]
    
    for i in range(str_len):
        out, h = myrnn.forward(x, h)
        
        out_dist = out.data.view(-1).div(temperature).exp()
        sample = torch.multinomial(out_dist, 1)[0]
        pred_char = num_to_let[sample.item()]
        
        generated += pred_char
        
        x = Variable(torch.LongTensor([sample]))
    
    return generated
        
    

gen = generate('cool i am fine', 1500, 0.75)
#gen = generate('b', 1500, 0.75)


print(gen)
# Out:
# cool i am fine
# time your heard in the matrix
# dodgin' bullets, reapin' what you sow
# and stackin' up the footage, livin' on the game, got the whole world talkin' (king kunta)
# everybody wanna cut the legs off him (king kunta) kunta
# black man taking no losses
# bitch where you when i was walkin'?
# now i run the game, got the whole world talkin' (king kunta)
# everybody wanna cut the legs off him (king kunta) kunta
# black man taking no losses
# bitch, i did that!"
# x-rated
#
# johnny don't wanna go to school no mo', nommi's no contest
# if you like it, i love it, all your earth tones
# buna bluese hame, phin’ movie screens
# and spike yourself esteem
# the new james bond gon’ be black as me
# black as brown, hazelnut, cinnamon, black man taking no losses
# bitch where you when i was walkin'?
# now i run the game, got the whole world talkin' (king kunta)
# everybody wanna cut the legs off him (king kunta) kunta
# black man taking no losses
# bitch, i did that!"
# x-rated
#
# johnny don't wanna go to school no mo', no mo'
# johnny said books ain't cool no mo' (no mo')
# johnny wanna be a rapper with a ghost writer
# what the fuck happened?
# (oh no) i swore i tould fight less and we would talk more
# and is paliset in the matrix
# dodgin' bullets, reapin' what you sow
# and stackin' up the footage, livin' on the go
# and sleppin' kiloos
# girl, i can be uy and crive a buttorol, a nigga
# i'm a spat african girl, you too busy fucking with your
# hope waid to self-destruct
# the gim, love is not just a verb
# it's you looking for it, maybe, call me crazy, we c
